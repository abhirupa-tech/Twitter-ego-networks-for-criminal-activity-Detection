# %%
import os
import tweepy as tw
import pandas as pd

# %%
consumer_key= 'lL5jwhZjazxKKy4WUJkcRHsLb'
consumer_secret= 'r2f5XZ8f2bNtFSY72QZfdtrsNglGzIeRaHva2LoyZpVs14i0i8'
access_token= '995760376808591361-Lkl0hmd0zsjCopgGZgf4sbWppCWOYqb'
access_token_secret= 'ZMk77Ahi4s9IEfiCiK7riU7BeR6D7LG4C8o2We4pJpVa4'

# %%
#Module to fetch the last 200 tweets of a suspected user


auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)


prefixes=('@','#','http')
retweet=('RT')
def get_tweets(username): 
          
        auth = tw.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        api = tw.API(auth, wait_on_rate_limit=True)  
        
        # 200 tweets to be extracted 
        number_of_tweets=200
        tweets = api.user_timeline(screen_name=username, q="#* -filter:retweets") 
  
        # Empty Array 
        tmp=[] 
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
            #print (j,"\n")
            #clean text, split into words and rmeove hyperlinks, hashtags and @
            x=j.split()
            #print(x)
            for word in x[:]:
                if word.startswith(prefixes):
                    x.remove(word)
            
            #print(x)
            j=' '.join(word for word in x)
  
            # Appending tweets to the empty array tmp 
            if(j!=''):
                tmp.append(j)  
  
        # Printing the tweets 
        return tmp

# %%
df=pd.read_csv("CSV_files/Crime_Flagged.csv")
df
# Out:
#    Unnamed: 0             User       Location  \
# 0           0           atxleb            NaN
# 1           1   ShayneOfficial            NaN
# 2           2       JamesJgm26            NaN
# 3           3      VerucaMarie            NaN
# 4           4  Her_Masterpiece  New York, USA
#
#                                                Tweet  Flag           1  \
# 0  Because they’d be prosecuting government offic...   0.0  analytical
# 1  It’s actually cheaper to eat on the right. Tha...   0.0         joy
# 2    I will kill trump just to piss off the Russians   1.0       anger
# 3  always. We had to put the rock to sleep early ...   1.0  analytical
# 4  Just passed by a house with their icicle light...   0.0   tentative
#
#            2   3   4
# 0        NaN NaN NaN
# 1        NaN NaN NaN
# 2  tentative NaN NaN
# 3  confident NaN NaN
# 4        NaN NaN NaN

# %%
import json
for i in df.itertuples():
    flag=i[5]
    if(flag==1):
        user=i[2]
        print("Suspected:",user)
        #Get all tweets from this user
        #Generate ego network for the user
        # Here goes the twitter handle for the user whose tweets are to be extracted. 
        cleanedtweet=get_tweets(user)  
        d={}#The dictionary
        dlist=[]#The list to append the dictionary to

        for j in cleanedtweet:
            d={}
            d['content']=j
            d['contenttype']="text/plain"
            d['created']= 0
            d['id']=i[1]
            d['language']= "en"
            dlist.append(d)
            #print(d,"\n")
        #print(dlist,"\n")
        with open('profile_demo.json', 'w') as outfile:
            json.dump({'contentItems': dlist}, outfile,indent=4)
        
        #Connect with Watson Personlity Insight
        from ibm_watson import PersonalityInsightsV3
        from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

        authenticator = IAMAuthenticator('4_vyfrdyUkp31NVo934SJ0QLkX1-oeIxUrcDSiNLUGW7')
        personality_insights = PersonalityInsightsV3(
            version='2017-10-13',
            authenticator=authenticator
        )
        personality_insights.set_service_url('https://api.eu-gb.personality-insights.watson.cloud.ibm.com/instances/2d350496-9675-4cc6-8ecc-1b2919b69e5c')

print("Execution over")
# Out:
# Suspected: JamesJgm26
# [{'content': 'RT Moneybagg Yo previews new banger', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': "RT Ce soir, Clinton Sparks dévoilera un vieux freestyle inédit d'Eminem. Les 2, ont travaillé plusieurs fois ensemble, mais l…", 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT Dog smelled to much', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT Cocky AF and my friends Cocky too 😉', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT The tiktok ended before It could even start☠️😭', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT What in the unseasoned chicken is this 😂😂🤦🏾\u200d♂️ Challenge Over 💀', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT 2020:', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT rihanna said here’s some crumbs eat it bitch', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': "RT how have I never noticed Stan's reflection on the window????", 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': "RT Hi there, Bitch, My name is Marsh and, I'm out this world. S on my chest (Superman) like it's plural. Call me extra, extra…", 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT \U0001f97a\U0001f97a\U0001f97a\U0001f97a\U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT Niggas arguing bout OHIO LMFAOOOOOOOOOO', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT my mum wants to start a fashion blog in her spare time so i told her to start with a tiktok and \U0001f97a👉🏽👈🏽...', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT grama &amp; dukes wanted to get loose 😂🔥🐐', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT This guy has just won the internet.', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT Nobody: Gfs alone with they bf kid for 10 seconds:', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'Im getting this🖕from everyone about 2005 set up lol suck shit suck my dick lol', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT Just in case you need it, here’s a dog doing yoga in Italian. You’re welcome.', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}, {'content': 'RT 3 different flows in 40 seconds. Who’s doing it like Nicki Minaj? \U0001f975', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}]
#
# Suspected: VerucaMarie
# [{'content': 'This was 11 or 12 years ago but I was SUPER excited about it.', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'Everyone else seems to have had a much different experience than I did with Overton…', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'I was just saying the other day that if Mackenzie donated some cash to the families that are strugglin…', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "Maybe it's just me, but I feel like Mackenzie Bezos could make Jeff look like the biggest tool walking the planet…", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'Beautiful! It reminds me of a makeup look that did in a video.', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "Lord knows this state could use any help it can get. LoL. I'll start with a kit kat…", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'Unless you count my crush at 5 years old, which was Jon, or Joey or Donnie. LoL', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "What the hell! When did these become a thing and why aren't they sold in Michigan! I need to try these.", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'My 7 year old is obsessed with so obsessed in fact that she has the game on the xbox and her phone…', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'This is the play vs', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "Too hard. I don't think I could every pick just 3.", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'We can agree on this.... I root for a different team but I really do miss baseball.', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "That just means my guys are due. Plus I might be wrong (I'm not) but I'm pretty sure…", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'Wanna fight?', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'RT I’m giving away $1,000 to 3 random people who retweet this in the next 72 hours. Must be following me so I can dm you…', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "I never win anything but man it's worth a try. Your girl is struggling!", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "My husband sings but his voice is more soul - idk if it would fit with a wrestling theme. But it's pret…", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': 'So wonderful! 💜💜', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}, {'content': "I'd want some myself if they were better colors. For example, a little Honolulu blue…", 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}]
#
# Execution over

# %%
#create a list of dictionaries to later import it into json format that is accepted by Watson
df=tweet_data
d={}#The dictionary
dlist=[]#The list to append the dictionary to

for i in df.itertuples():
    d={}
    d['content']=i[3]
    d['contenttype']="text/plain"
    d['created']= 0
    d['id']= i[0]
    d['language']= "en"
    dlist.append(d)
    print(d,"\n")

# %%
# Out:
# Hello
