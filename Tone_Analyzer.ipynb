# %%
from ibm_watson import ToneAnalyzerV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('IqEdRTVdqJlT8caIhis9hxNC90nzKvj0VFwN5CVdA0MI')
tone_analyzer = ToneAnalyzerV3(
     version='2017-09-21',
    authenticator=authenticator
)

tone_analyzer.set_service_url('https://api.us-east.tone-analyzer.watson.cloud.ibm.com')

# %%
from ibm_watson import ApiException
try:
    print("Watson Tone Analyzer initialized")
except ApiException as ex:
    print( "Method failed with status code " + str(ex.code) + ": " + ex.message)
# Out:
# Watson Tone Analyzer initialized

# %%
import json

tone_analyzer.set_service_url('https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/1ea8911e-feb9-4174-8ce1-1379339ea808')

text = 'If Zimmmerman free imma shoot everybody in Zion causing a ma ..'

tone_analysis = tone_analyzer.tone(
    {'text': text},
    content_type='application/json'
).get_result()
print(json.dumps(tone_analysis, indent=2))
# Out:
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.862286,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   }
# }

# %%
import pandas as pd
df_demo=pd.read_csv("demodata.csv")
df_demo
# Out:
#               User       Location  \
# 0           atxleb            NaN
# 1   ShayneOfficial            NaN
# 2       JamesJgm26            NaN
# 3      VerucaMarie            NaN
# 4  Her_Masterpiece  New York, USA
#
#                                                Tweet
# 0  @theinstantwin @JKDAnthony10 @grantstern @TheD...
# 1  @SailorZZtar It’s actually cheaper to eat on t...
# 2    I will kill trump just to piss off the Russians
# 3  @DJSlash always. We had to put the rock to sle...
# 4  Just passed by a house with their icicle light...

# %%
for i in df_demo.itertuples():
    tone_analyzer.set_service_url('https://api.eu-gb.tone-analyzer.watson.cloud.ibm.com/instances/1ea8911e-feb9-4174-8ce1-1379339ea808')
    text = i[3]
    print(text)
    tone_analysis = tone_analyzer.tone(
        {'text': text},
        content_type='application/json'
    ).get_result()
    print(json.dumps(tone_analysis, indent=2))
# Out:
# @theinstantwin @JKDAnthony10 @grantstern @TheDemCoalition Because they’d be prosecuting government officials?
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.687768,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   }
# }
# @SailorZZtar It’s actually cheaper to eat on the right. That’s multiple days worth of food. The McD’s is just one meal during the day
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.561425,
#         "tone_id": "joy",
#         "tone_name": "Joy"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "@SailorZZtar It\u2019s actually cheaper to eat on the right.",
#       "tones": [
#         {
#           "score": 0.874372,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 1,
#       "text": "That\u2019s multiple days worth of food.",
#       "tones": [
#         {
#           "score": 0.619481,
#           "tone_id": "joy",
#           "tone_name": "Joy"
#         }
#       ]
#     },
#     {
#       "sentence_id": 2,
#       "text": "The McD\u2019s is just one meal during the day",
#       "tones": [
#         {
#           "score": 0.856622,
#           "tone_id": "tentative",
#           "tone_name": "Tentative"
#         }
#       ]
#     }
#   ]
# }
# I will kill trump just to piss off the Russians
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.645335,
#         "tone_id": "anger",
#         "tone_name": "Anger"
#       },
#       {
#         "score": 0.822231,
#         "tone_id": "tentative",
#         "tone_name": "Tentative"
#       }
#     ]
#   }
# }
# @DJSlash always. We had to put the rock to sleep early tonight because Layla was really tired.
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.982688,
#         "tone_id": "confident",
#         "tone_name": "Confident"
#       },
#       {
#         "score": 0.908592,
#         "tone_id": "analytical",
#         "tone_name": "Analytical"
#       }
#     ]
#   },
#   "sentences_tone": [
#     {
#       "sentence_id": 0,
#       "text": "@DJSlash always.",
#       "tones": [
#         {
#           "score": 0.996934,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         }
#       ]
#     },
#     {
#       "sentence_id": 1,
#       "text": "We had to put the rock to sleep early tonight because Layla was really tired.",
#       "tones": [
#         {
#           "score": 0.645985,
#           "tone_id": "confident",
#           "tone_name": "Confident"
#         },
#         {
#           "score": 0.801827,
#           "tone_id": "analytical",
#           "tone_name": "Analytical"
#         }
#       ]
#     }
#   ]
# }
# Just passed by a house with their icicle lights and wreath still up.
# {
#   "document_tone": {
#     "tones": [
#       {
#         "score": 0.716301,
#         "tone_id": "tentative",
#         "tone_name": "Tentative"
#       }
#     ]
#   }
# }
